# %%
# !pip uninstall protobuf -y
# Out:
# Found existing installation: protobuf 3.20.3
# Uninstalling protobuf-3.20.3:
#   Successfully uninstalled protobuf-3.20.3

# %%
# !pip install protobuf==3.20.3
# Out:
# Collecting protobuf==3.20.3
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Installing collected packages: protobuf
# Successfully installed protobuf-3.20.3

# %%
# !pip install sentence-transformers faiss-cpu transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\dhruti\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: faiss-cpu in c:\users\dhruti\anaconda3\lib\site-packages (1.14.2)
# Requirement already satisfied: transformers in c:\users\dhruti\anaconda3\lib\site-packages (4.41.2)
# Requirement already satisfied: tqdm in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: numpy in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: scipy in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers) (0.35.3)
# Requirement already satisfied: Pillow in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: packaging in c:\users\dhruti\anaconda3\lib\site-packages (from faiss-cpu) (23.2)
# Requirement already satisfied: filelock in c:\users\dhruti\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\dhruti\anaconda3\lib\site-packages (from transformers) (2.32.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dhruti\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dhruti\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (69.5.1)
# Requirement already satisfied: colorama in c:\users\dhruti\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dhruti\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dhruti\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dhruti\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dhruti\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)

# %%
# !pip install transformers==4.41.2 sentence-transformers==2.7.0
# Out:
# Requirement already satisfied: transformers==4.41.2 in c:\users\dhruti\anaconda3\lib\site-packages (4.41.2)
# Requirement already satisfied: sentence-transformers==2.7.0 in c:\users\dhruti\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: filelock in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (2023.10.3)
# Requirement already satisfied: requests in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (2.32.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dhruti\anaconda3\lib\site-packages (from transformers==4.41.2) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers==2.7.0) (2.9.0)
# Requirement already satisfied: scikit-learn in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers==2.7.0) (1.4.2)
# Requirement already satisfied: scipy in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers==2.7.0) (1.13.1)
# Requirement already satisfied: Pillow in c:\users\dhruti\anaconda3\lib\site-packages (from sentence-transformers==2.7.0) (10.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dhruti\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dhruti\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==2.7.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==2.7.0) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==2.7.0) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\dhruti\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==2.7.0) (69.5.1)
# Requirement already satisfied: colorama in c:\users\dhruti\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.41.2) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers==4.41.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers==4.41.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers==4.41.2) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhruti\anaconda3\lib\site-packages (from requests->transformers==4.41.2) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dhruti\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers==2.7.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dhruti\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers==2.7.0) (2.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dhruti\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers==2.7.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dhruti\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers==2.7.0) (2.1.3)

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

embeddings = model.encode(all_messages)

print("Embeddings created!")
print(embeddings.shape)
